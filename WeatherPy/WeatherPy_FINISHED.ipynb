# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime
import os

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %% [markdown]
# ## Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# initial_cities_list = ['amderma',
#  'samusu',
#  'albany',
#  'jalu',
#  'qaqortoq',
#  'hermanus',
#  'belushya guba',
#  'jamestown',
#  'luderitz',
#  'khatanga',
#  'rawson',
#  'norman wells',
#  'sentyabrskiy',
#  'hithadhoo',
#  'palabuhanratu',
#  'busselton',
#  'torbay',
#  'barrow',
#  'punta arenas']

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?"
city_list = []
max_temp_list = []
lat_list = []
lon_list = []
humidity_list = []
cloudiness_list = []
wind_list = []
country_list = []
date_list = []

print("------------------------") 
print("Beginning Data Retrieval")
print("------------------------")

for city in cities:
    
    city_name = city
    
    try:
        
        query_url = f"{url}appid={weather_api_key}&q={city_name}&units=imperial"
        
        weather_summary = requests.get(query_url).json()
        
        print(f"Processing Record {city} of Set {len(cities)} | {city_name}")
        
        max_temp_list.append(weather_summary["main"]["temp_max"])
        
        lat_list.append(weather_summary["coord"]["lat"])
        
        lon_list.append(weather_summary["coord"]["lon"])
        
        humidity_list.append(weather_summary["main"]["humidity"])
        
        cloudiness_list.append(weather_summary["clouds"]["all"])
        
        wind_list.append(weather_summary["wind"]["speed"])
        
        country_list.append(weather_summary["sys"]["country"])
        
        date_list.append(weather_summary["dt"])
        
        city_list.append(city_name)
        
        print(f"{city_name} found. Record completed.")
        
    except KeyError:
        print(f"{city_name} not found. Skipping...")
        
    time.sleep(1)

print("------------------------")            
print("Data Retrieval Complete")
print("------------------------")
# Out:
# ------------------------
# Beginning Data Retrieval
# ------------------------
# Processing Record rikitea of Set 607 | rikitea
# rikitea found. Record completed.
# Processing Record saint-philippe of Set 607 | saint-philippe
# saint-philippe found. Record completed.
# Processing Record ribeira grande of Set 607 | ribeira grande
# ribeira grande found. Record completed.
# Processing Record georgetown of Set 607 | georgetown
# georgetown found. Record completed.
# Processing Record chuy of Set 607 | chuy
# chuy found. Record completed.
# Processing Record ahipara of Set 607 | ahipara
# ahipara found. Record completed.
# Processing Record vila franca do campo of Set 607 | vila franca do campo
# vila franca do campo found. Record completed.
# Processing Record burica of Set 607 | burica
# burica not found. Skipping...
# Processing Record bethel of Set 607 | bethel
# bethel found. Record completed.
# Processing Record otjimbingwe of Set 607 | otjimbingwe
# otjimbingwe found. Record completed.
# Processing Record barrow of Set 607 | barrow
# barrow found. Record completed.
# Processing Record constitucion of Set 607 | constitucion
# constitucion found. Record completed.
# Processing Record atar of Set 607 | atar
# atar found. Record completed.
# Processing Record port elizabeth of Set 607 | port elizabeth
# port elizabeth found. Record completed.
# Processing Record esperance of Set 607 | esperance
# esperance found. Record completed.
# Processing Record adrar of Set 607 | adrar
# adrar found. Record completed.
# Processing Record carnarvon of Set 607 | carnarvon
# carnarvon found. Record completed.
# Processing Record sumbawanga of Set 607 | sumbawanga
# sumbawanga found. Record completed.
# Processing Record vaini of Set 607 | vaini
# vaini found. Record completed.
# Processing Record ihosy of Set 607 | ihosy
# ihosy found. Record completed.
# Processing Record chapais of Set 607 | chapais
# chapais found. Record completed.
# Processing Record norman wells of Set 607 | norman wells
# norman wells found. Record completed.
# Processing Record port alfred of Set 607 | port alfred
# port alfred found. Record completed.
# Processing Record umzimvubu of Set 607 | umzimvubu
# umzimvubu not found. Skipping...
# Processing Record hermanus of Set 607 | hermanus
# hermanus found. Record completed.
# Processing Record hobart of Set 607 | hobart
# hobart found. Record completed.
# Processing Record bredasdorp of Set 607 | bredasdorp
# bredasdorp found. Record completed.
# Processing Record jamestown of Set 607 | jamestown
# jamestown found. Record completed.
# Processing Record illoqqortoormiut of Set 607 | illoqqortoormiut
# illoqqortoormiut not found. Skipping...
# Processing Record panlaitan of Set 607 | panlaitan
# panlaitan found. Record completed.
# Processing Record conchagua of Set 607 | conchagua
# conchagua found. Record completed.
# Processing Record saldanha of Set 607 | saldanha
# saldanha found. Record completed.
# Processing Record east london of Set 607 | east london
# east london found. Record completed.
# Processing Record oussouye of Set 607 | oussouye
# oussouye found. Record completed.
# Processing Record honiara of Set 607 | honiara
# honiara found. Record completed.
# Processing Record cape town of Set 607 | cape town
# cape town found. Record completed.
# Processing Record atuona of Set 607 | atuona
# atuona found. Record completed.
# Processing Record bhimunipatnam of Set 607 | bhimunipatnam
# bhimunipatnam found. Record completed.
# Processing Record tasiilaq of Set 607 | tasiilaq
# tasiilaq found. Record completed.
# Processing Record punta arenas of Set 607 | punta arenas
# punta arenas found. Record completed.
# Processing Record kimbe of Set 607 | kimbe
# kimbe found. Record completed.
# Processing Record bambous virieux of Set 607 | bambous virieux
# bambous virieux found. Record completed.
# Processing Record dikson of Set 607 | dikson
# dikson found. Record completed.
# Processing Record alofi of Set 607 | alofi
# alofi found. Record completed.
# Processing Record mocuba of Set 607 | mocuba
# mocuba found. Record completed.
# Processing Record busselton of Set 607 | busselton
# busselton found. Record completed.
# Processing Record corinto of Set 607 | corinto
# corinto found. Record completed.
# Processing Record kamenskiy of Set 607 | kamenskiy
# kamenskiy found. Record completed.
# Processing Record nagua of Set 607 | nagua
# nagua found. Record completed.
# Processing Record mandalgovi of Set 607 | mandalgovi
# mandalgovi found. Record completed.
# Processing Record san cristobal of Set 607 | san cristobal
# san cristobal found. Record completed.
# Processing Record lompoc of Set 607 | lompoc
# lompoc found. Record completed.
# Processing Record qaanaaq of Set 607 | qaanaaq
# qaanaaq found. Record completed.
# Processing Record albany of Set 607 | albany
# albany found. Record completed.
# Processing Record ossora of Set 607 | ossora
# ossora found. Record completed.
# Processing Record hilo of Set 607 | hilo
# hilo found. Record completed.
# Processing Record san jose of Set 607 | san jose
# san jose found. Record completed.
# Processing Record mezen of Set 607 | mezen
# mezen found. Record completed.
# Processing Record mataura of Set 607 | mataura
# mataura found. Record completed.
# Processing Record almunecar of Set 607 | almunecar
# almunecar found. Record completed.
# Processing Record abu kamal of Set 607 | abu kamal
# abu kamal found. Record completed.
# Processing Record baft of Set 607 | baft
# baft found. Record completed.
# Processing Record bluff of Set 607 | bluff
# bluff found. Record completed.
# Processing Record ushuaia of Set 607 | ushuaia
# ushuaia found. Record completed.
# Processing Record dunedin of Set 607 | dunedin
# dunedin found. Record completed.
# Processing Record minot of Set 607 | minot
# minot found. Record completed.
# Processing Record nizhneyansk of Set 607 | nizhneyansk
# nizhneyansk not found. Skipping...
# Processing Record shingu of Set 607 | shingu
# shingu found. Record completed.
# Processing Record mahebourg of Set 607 | mahebourg
# mahebourg found. Record completed.
# Processing Record griffith of Set 607 | griffith
# griffith found. Record completed.
# Processing Record antalaha of Set 607 | antalaha
# antalaha found. Record completed.
# Processing Record bintulu of Set 607 | bintulu
# bintulu found. Record completed.
# Processing Record puerto ayora of Set 607 | puerto ayora
# puerto ayora found. Record completed.
# Processing Record lebu of Set 607 | lebu
# lebu found. Record completed.
# Processing Record rio grande of Set 607 | rio grande
# rio grande found. Record completed.
# Processing Record abiy adi of Set 607 | abiy adi
# abiy adi not found. Skipping...
# Processing Record waiouru of Set 607 | waiouru
# waiouru found. Record completed.
# Processing Record ilulissat of Set 607 | ilulissat
# ilulissat found. Record completed.
# Processing Record ganzhou of Set 607 | ganzhou
# ganzhou found. Record completed.
# Processing Record moranbah of Set 607 | moranbah
# moranbah found. Record completed.
# Processing Record tsumeb of Set 607 | tsumeb
# tsumeb found. Record completed.
# Processing Record abnub of Set 607 | abnub
# abnub found. Record completed.
# Processing Record fallon of Set 607 | fallon
# fallon found. Record completed.
# Processing Record butaritari of Set 607 | butaritari
# butaritari found. Record completed.
# Processing Record yulara of Set 607 | yulara
# yulara found. Record completed.
# Processing Record baffa of Set 607 | baffa
# baffa found. Record completed.
# Processing Record cherepovets of Set 607 | cherepovets
# cherepovets found. Record completed.
# Processing Record port blair of Set 607 | port blair
# port blair found. Record completed.
# Processing Record qaqortoq of Set 607 | qaqortoq
# qaqortoq found. Record completed.
# Processing Record lagoa of Set 607 | lagoa
# lagoa found. Record completed.
# Processing Record new norfolk of Set 607 | new norfolk
# new norfolk found. Record completed.
# Processing Record provideniya of Set 607 | provideniya
# provideniya found. Record completed.
# Processing Record farmington of Set 607 | farmington
# farmington found. Record completed.
# Processing Record juybar of Set 607 | juybar
# juybar found. Record completed.
# Processing Record buraydah of Set 607 | buraydah
# buraydah found. Record completed.
# Processing Record thompson of Set 607 | thompson
# thompson found. Record completed.
# Processing Record gornyy of Set 607 | gornyy
# gornyy found. Record completed.
# Processing Record lao cai of Set 607 | lao cai
# lao cai found. Record completed.
# Processing Record antofagasta of Set 607 | antofagasta
# antofagasta found. Record completed.
# Processing Record vila velha of Set 607 | vila velha
# vila velha found. Record completed.
# Processing Record cap malheureux of Set 607 | cap malheureux
# cap malheureux found. Record completed.
# Processing Record abu samrah of Set 607 | abu samrah
# abu samrah found. Record completed.
# Processing Record arraial do cabo of Set 607 | arraial do cabo
# arraial do cabo found. Record completed.
# Processing Record iqaluit of Set 607 | iqaluit
# iqaluit found. Record completed.
# Processing Record disna of Set 607 | disna
# disna found. Record completed.
# Processing Record kiruna of Set 607 | kiruna
# kiruna found. Record completed.
# Processing Record cidreira of Set 607 | cidreira
# cidreira found. Record completed.
# Processing Record tautira of Set 607 | tautira
# tautira found. Record completed.
# Processing Record kapaa of Set 607 | kapaa
# kapaa found. Record completed.
# Processing Record sao joao da barra of Set 607 | sao joao da barra
# sao joao da barra found. Record completed.
# Processing Record cartagena of Set 607 | cartagena
# cartagena found. Record completed.
# Processing Record bubaque of Set 607 | bubaque
# bubaque found. Record completed.
# Processing Record grand river south east of Set 607 | grand river south east
# grand river south east not found. Skipping...
# Processing Record windhoek of Set 607 | windhoek
# windhoek found. Record completed.
# Processing Record nome of Set 607 | nome
# nome found. Record completed.
# Processing Record ballina of Set 607 | ballina
# ballina found. Record completed.
# Processing Record cabo san lucas of Set 607 | cabo san lucas
# cabo san lucas found. Record completed.
# Processing Record belushya guba of Set 607 | belushya guba
# belushya guba not found. Skipping...
# Processing Record manaskent of Set 607 | manaskent
# manaskent found. Record completed.
# Processing Record sosnovo-ozerskoye of Set 607 | sosnovo-ozerskoye
# sosnovo-ozerskoye found. Record completed.
# Processing Record alice town of Set 607 | alice town
# alice town found. Record completed.
# Processing Record cherskiy of Set 607 | cherskiy
# cherskiy found. Record completed.
# Processing Record porbandar of Set 607 | porbandar
# porbandar found. Record completed.
# Processing Record nikolskoye of Set 607 | nikolskoye
# nikolskoye found. Record completed.
# Processing Record baracoa of Set 607 | baracoa
# baracoa found. Record completed.
# Processing Record brae of Set 607 | brae
# brae found. Record completed.
# Processing Record cedar city of Set 607 | cedar city
# cedar city found. Record completed.
# Processing Record juneau of Set 607 | juneau
# juneau found. Record completed.
# Processing Record valparaiso of Set 607 | valparaiso
# valparaiso found. Record completed.
# Processing Record tuktoyaktuk of Set 607 | tuktoyaktuk
# tuktoyaktuk found. Record completed.
# Processing Record havoysund of Set 607 | havoysund
# havoysund found. Record completed.
# Processing Record kaitangata of Set 607 | kaitangata
# kaitangata found. Record completed.
# Processing Record vardo of Set 607 | vardo
# vardo found. Record completed.
# Processing Record fuerte olimpo of Set 607 | fuerte olimpo
# fuerte olimpo found. Record completed.
# Processing Record muncar of Set 607 | muncar
# muncar found. Record completed.
# Processing Record kutum of Set 607 | kutum
# kutum found. Record completed.
# Processing Record mwinilunga of Set 607 | mwinilunga
# mwinilunga found. Record completed.
# Processing Record taolanaro of Set 607 | taolanaro
# taolanaro not found. Skipping...
# Processing Record voyvozh of Set 607 | voyvozh
# voyvozh found. Record completed.
# Processing Record bojnurd of Set 607 | bojnurd
# bojnurd found. Record completed.
# Processing Record beibei of Set 607 | beibei
# beibei found. Record completed.
# Processing Record muros of Set 607 | muros
# muros found. Record completed.
# Processing Record rabat of Set 607 | rabat
# rabat found. Record completed.
# Processing Record barentsburg of Set 607 | barentsburg
# barentsburg not found. Skipping...
# Processing Record padang of Set 607 | padang
# padang found. Record completed.
# Processing Record chokurdakh of Set 607 | chokurdakh
# chokurdakh found. Record completed.
# Processing Record mys shmidta of Set 607 | mys shmidta
# mys shmidta not found. Skipping...
# Processing Record sentyabrskiy of Set 607 | sentyabrskiy
# sentyabrskiy not found. Skipping...
# Processing Record yenagoa of Set 607 | yenagoa
# yenagoa found. Record completed.
# Processing Record wajir of Set 607 | wajir
# wajir found. Record completed.
# Processing Record kruisfontein of Set 607 | kruisfontein
# kruisfontein found. Record completed.
# Processing Record tiksi of Set 607 | tiksi
# tiksi found. Record completed.
# Processing Record eureka of Set 607 | eureka
# eureka found. Record completed.
# Processing Record yellowknife of Set 607 | yellowknife
# yellowknife found. Record completed.
# Processing Record bilibino of Set 607 | bilibino
# bilibino found. Record completed.
# Processing Record kangaatsiaq of Set 607 | kangaatsiaq
# kangaatsiaq found. Record completed.
# Processing Record asau of Set 607 | asau
# asau found. Record completed.
# Processing Record zhezkazgan of Set 607 | zhezkazgan
# zhezkazgan found. Record completed.
# Processing Record svetlogorsk of Set 607 | svetlogorsk
# svetlogorsk found. Record completed.
# Processing Record dingle of Set 607 | dingle
# dingle found. Record completed.
# Processing Record te anau of Set 607 | te anau
# te anau found. Record completed.
# Processing Record leningradskiy of Set 607 | leningradskiy
# leningradskiy found. Record completed.
# Processing Record awjilah of Set 607 | awjilah
# awjilah found. Record completed.
# Processing Record kodiak of Set 607 | kodiak
# kodiak found. Record completed.
# Processing Record upernavik of Set 607 | upernavik
# upernavik found. Record completed.
# Processing Record tecoanapa of Set 607 | tecoanapa
# tecoanapa found. Record completed.
# Processing Record vaitupu of Set 607 | vaitupu
# vaitupu not found. Skipping...
# Processing Record george town of Set 607 | george town
# george town found. Record completed.
# Processing Record uspenskaya of Set 607 | uspenskaya
# uspenskaya found. Record completed.
# Processing Record mar del plata of Set 607 | mar del plata
# mar del plata found. Record completed.
# Processing Record paita of Set 607 | paita
# paita found. Record completed.
# Processing Record kerewan of Set 607 | kerewan
# kerewan found. Record completed.
# Processing Record port hardy of Set 607 | port hardy
# port hardy found. Record completed.
# Processing Record sao felix do xingu of Set 607 | sao felix do xingu
# sao felix do xingu found. Record completed.
# Processing Record san patricio of Set 607 | san patricio
# san patricio found. Record completed.
# Processing Record henties bay of Set 607 | henties bay
# henties bay found. Record completed.
# Processing Record khasan of Set 607 | khasan
# khasan found. Record completed.
# Processing Record isangel of Set 607 | isangel
# isangel found. Record completed.
# Processing Record saint george of Set 607 | saint george
# saint george found. Record completed.
# Processing Record tumannyy of Set 607 | tumannyy
# tumannyy not found. Skipping...
# Processing Record luderitz of Set 607 | luderitz
# luderitz found. Record completed.
# Processing Record anadyr of Set 607 | anadyr
# anadyr found. Record completed.
# Processing Record ponta do sol of Set 607 | ponta do sol
# ponta do sol found. Record completed.
# Processing Record rio de janeiro of Set 607 | rio de janeiro
# rio de janeiro found. Record completed.
# Processing Record jasper of Set 607 | jasper
# jasper found. Record completed.
# Processing Record kununurra of Set 607 | kununurra
# kununurra found. Record completed.
# Processing Record hay river of Set 607 | hay river
# hay river found. Record completed.
# Processing Record khatanga of Set 607 | khatanga
# khatanga found. Record completed.
# Processing Record salalah of Set 607 | salalah
# salalah found. Record completed.
# Processing Record amapa of Set 607 | amapa
# amapa found. Record completed.
# Processing Record outlook of Set 607 | outlook
# outlook found. Record completed.
# Processing Record gomez plata of Set 607 | gomez plata
# gomez plata found. Record completed.
# Processing Record tatawin of Set 607 | tatawin
# tatawin found. Record completed.
# Processing Record olafsvik of Set 607 | olafsvik
# olafsvik found. Record completed.
# Processing Record nouakchott of Set 607 | nouakchott
# nouakchott found. Record completed.
# Processing Record ribas do rio pardo of Set 607 | ribas do rio pardo
# ribas do rio pardo found. Record completed.
# Processing Record hambantota of Set 607 | hambantota
# hambantota found. Record completed.
# Processing Record nanortalik of Set 607 | nanortalik
# nanortalik found. Record completed.
# Processing Record turukhansk of Set 607 | turukhansk
# turukhansk found. Record completed.
# Processing Record porto novo of Set 607 | porto novo
# porto novo found. Record completed.
# Processing Record bolungarvik of Set 607 | bolungarvik
# bolungarvik not found. Skipping...
# Processing Record nowy targ of Set 607 | nowy targ
# nowy targ found. Record completed.
# Processing Record ouesso of Set 607 | ouesso
# ouesso found. Record completed.
# Processing Record zihuatanejo of Set 607 | zihuatanejo
# zihuatanejo found. Record completed.
# Processing Record huarmey of Set 607 | huarmey
# huarmey found. Record completed.
# Processing Record seoul of Set 607 | seoul
# seoul found. Record completed.
# Processing Record leshukonskoye of Set 607 | leshukonskoye
# leshukonskoye found. Record completed.
# Processing Record puerto barrios of Set 607 | puerto barrios
# puerto barrios found. Record completed.
# Processing Record bombay of Set 607 | bombay
# bombay found. Record completed.
# Processing Record labuhan of Set 607 | labuhan
# labuhan found. Record completed.
# Processing Record albion of Set 607 | albion
# albion found. Record completed.
# Processing Record lorengau of Set 607 | lorengau
# lorengau found. Record completed.
# Processing Record flin flon of Set 607 | flin flon
# flin flon found. Record completed.
# Processing Record faanui of Set 607 | faanui
# faanui found. Record completed.
# Processing Record christchurch of Set 607 | christchurch
# christchurch found. Record completed.
# Processing Record pimentel of Set 607 | pimentel
# pimentel found. Record completed.
# Processing Record klaksvik of Set 607 | klaksvik
# klaksvik found. Record completed.
# Processing Record los llanos de aridane of Set 607 | los llanos de aridane
# los llanos de aridane found. Record completed.
# Processing Record khangah dogran of Set 607 | khangah dogran
# khangah dogran found. Record completed.
# Processing Record sibolga of Set 607 | sibolga
# sibolga found. Record completed.
# Processing Record sabha of Set 607 | sabha
# sabha found. Record completed.
# Processing Record codrington of Set 607 | codrington
# codrington found. Record completed.
# Processing Record nyurba of Set 607 | nyurba
# nyurba found. Record completed.
# Processing Record qui nhon of Set 607 | qui nhon
# qui nhon found. Record completed.
# Processing Record liseleje of Set 607 | liseleje
# liseleje found. Record completed.
# Processing Record lodja of Set 607 | lodja
# lodja found. Record completed.
# Processing Record gornopravdinsk of Set 607 | gornopravdinsk
# gornopravdinsk found. Record completed.
# Processing Record xining of Set 607 | xining
# xining found. Record completed.
# Processing Record jacareacanga of Set 607 | jacareacanga
# jacareacanga found. Record completed.
# Processing Record tabukiniberu of Set 607 | tabukiniberu
# tabukiniberu not found. Skipping...
# Processing Record pahrump of Set 607 | pahrump
# pahrump found. Record completed.
# Processing Record torbay of Set 607 | torbay
# torbay found. Record completed.
# Processing Record biltine of Set 607 | biltine
# biltine found. Record completed.
# Processing Record mount gambier of Set 607 | mount gambier
# mount gambier found. Record completed.
# Processing Record piacabucu of Set 607 | piacabucu
# piacabucu found. Record completed.
# Processing Record tura of Set 607 | tura
# tura found. Record completed.
# Processing Record lasa of Set 607 | lasa
# lasa found. Record completed.
# Processing Record staryy krym of Set 607 | staryy krym
# staryy krym found. Record completed.
# Processing Record ijaki of Set 607 | ijaki
# ijaki not found. Skipping...
# Processing Record roald of Set 607 | roald
# roald found. Record completed.
# Processing Record dumka of Set 607 | dumka
# dumka found. Record completed.
# Processing Record geraldton of Set 607 | geraldton
# geraldton found. Record completed.
# Processing Record morondava of Set 607 | morondava
# morondava found. Record completed.
# Processing Record college of Set 607 | college
# college found. Record completed.
# Processing Record pisco of Set 607 | pisco
# pisco found. Record completed.
# Processing Record luena of Set 607 | luena
# luena found. Record completed.
# Processing Record naze of Set 607 | naze
# naze found. Record completed.
# Processing Record avarua of Set 607 | avarua
# avarua found. Record completed.
# Processing Record nur of Set 607 | nur
# nur found. Record completed.
# Processing Record zonguldak of Set 607 | zonguldak
# zonguldak found. Record completed.
# Processing Record tuatapere of Set 607 | tuatapere
# tuatapere found. Record completed.
# Processing Record wanxian of Set 607 | wanxian
# wanxian found. Record completed.
# Processing Record kawalu of Set 607 | kawalu
# kawalu found. Record completed.
# Processing Record blyznyuky of Set 607 | blyznyuky
# blyznyuky found. Record completed.
# Processing Record rreshen of Set 607 | rreshen
# rreshen found. Record completed.
# Processing Record guarapari of Set 607 | guarapari
# guarapari found. Record completed.
# Processing Record avera of Set 607 | avera
# avera found. Record completed.
# Processing Record yar-sale of Set 607 | yar-sale
# yar-sale found. Record completed.
# Processing Record jalu of Set 607 | jalu
# jalu found. Record completed.
# Processing Record nokia of Set 607 | nokia
# nokia found. Record completed.
# Processing Record yirol of Set 607 | yirol
# yirol not found. Skipping...
# Processing Record etoka of Set 607 | etoka
# etoka found. Record completed.
# Processing Record mount isa of Set 607 | mount isa
# mount isa found. Record completed.
# Processing Record chagda of Set 607 | chagda
# chagda not found. Skipping...
# Processing Record camocim of Set 607 | camocim
# camocim found. Record completed.
# Processing Record coos bay of Set 607 | coos bay
# coos bay found. Record completed.
# Processing Record amur of Set 607 | amur
# amur found. Record completed.
# Processing Record asfi of Set 607 | asfi
# asfi found. Record completed.
# Processing Record mokhsogollokh of Set 607 | mokhsogollokh
# mokhsogollokh found. Record completed.
# Processing Record birin of Set 607 | birin
# birin found. Record completed.
# Processing Record bathsheba of Set 607 | bathsheba
# bathsheba found. Record completed.
# Processing Record valdobbiadene of Set 607 | valdobbiadene
# valdobbiadene found. Record completed.
# Processing Record goderich of Set 607 | goderich
# goderich found. Record completed.
# Processing Record yarada of Set 607 | yarada
# yarada found. Record completed.
# Processing Record kardonikskaya of Set 607 | kardonikskaya
# kardonikskaya found. Record completed.
# Processing Record pekan of Set 607 | pekan
# pekan found. Record completed.
# Processing Record san juan of Set 607 | san juan
# san juan found. Record completed.
# Processing Record gbarnga of Set 607 | gbarnga
# gbarnga found. Record completed.
# Processing Record mufulira of Set 607 | mufulira
# mufulira found. Record completed.
# Processing Record tera of Set 607 | tera
# tera found. Record completed.
# Processing Record gat of Set 607 | gat
# gat found. Record completed.
# Processing Record russell of Set 607 | russell
# russell found. Record completed.
# Processing Record fecamp of Set 607 | fecamp
# fecamp found. Record completed.
# Processing Record conselheiro pena of Set 607 | conselheiro pena
# conselheiro pena found. Record completed.
# Processing Record hit of Set 607 | hit
# hit found. Record completed.
# Processing Record havelock of Set 607 | havelock
# havelock found. Record completed.
# Processing Record honningsvag of Set 607 | honningsvag
# honningsvag found. Record completed.
# Processing Record ardee of Set 607 | ardee
# ardee found. Record completed.
# Processing Record traverse city of Set 607 | traverse city
# traverse city found. Record completed.
# Processing Record piranshahr of Set 607 | piranshahr
# piranshahr found. Record completed.
# Processing Record minsk of Set 607 | minsk
# minsk found. Record completed.
# Processing Record stornoway of Set 607 | stornoway
# stornoway found. Record completed.
# Processing Record praxedis guerrero of Set 607 | praxedis guerrero
# praxedis guerrero found. Record completed.
# Processing Record ewa beach of Set 607 | ewa beach
# ewa beach found. Record completed.
# Processing Record tsihombe of Set 607 | tsihombe
# tsihombe not found. Skipping...
# Processing Record souillac of Set 607 | souillac
# souillac found. Record completed.
# Processing Record pinega of Set 607 | pinega
# pinega found. Record completed.
# Processing Record marcona of Set 607 | marcona
# marcona not found. Skipping...
# Processing Record tual of Set 607 | tual
# tual found. Record completed.
# Processing Record vangaindrano of Set 607 | vangaindrano
# vangaindrano found. Record completed.
# Processing Record sibut of Set 607 | sibut
# sibut found. Record completed.
# Processing Record lobito of Set 607 | lobito
# lobito found. Record completed.
# Processing Record kodinsk of Set 607 | kodinsk
# kodinsk found. Record completed.
# Processing Record castro of Set 607 | castro
# castro found. Record completed.
# Processing Record haines junction of Set 607 | haines junction
# haines junction found. Record completed.
# Processing Record arak of Set 607 | arak
# arak found. Record completed.
# Processing Record itoman of Set 607 | itoman
# itoman found. Record completed.
# Processing Record am timan of Set 607 | am timan
# am timan found. Record completed.
# Processing Record kaset sombun of Set 607 | kaset sombun
# kaset sombun found. Record completed.
# Processing Record waingapu of Set 607 | waingapu
# waingapu found. Record completed.
# Processing Record wahran of Set 607 | wahran
# wahran not found. Skipping...
# Processing Record deputatskiy of Set 607 | deputatskiy
# deputatskiy found. Record completed.
# Processing Record wanning of Set 607 | wanning
# wanning found. Record completed.
# Processing Record bihar of Set 607 | bihar
# bihar found. Record completed.
# Processing Record alugan of Set 607 | alugan
# alugan found. Record completed.
# Processing Record erzin of Set 607 | erzin
# erzin found. Record completed.
# Processing Record pevek of Set 607 | pevek
# pevek found. Record completed.
# Processing Record hithadhoo of Set 607 | hithadhoo
# hithadhoo found. Record completed.
# Processing Record azul of Set 607 | azul
# azul found. Record completed.
# Processing Record bor of Set 607 | bor
# bor found. Record completed.
# Processing Record acajutla of Set 607 | acajutla
# acajutla found. Record completed.
# Processing Record ostrovnoy of Set 607 | ostrovnoy
# ostrovnoy found. Record completed.
# Processing Record saleaula of Set 607 | saleaula
# saleaula not found. Skipping...
# Processing Record chumikan of Set 607 | chumikan
# chumikan found. Record completed.
# Processing Record pangnirtung of Set 607 | pangnirtung
# pangnirtung found. Record completed.
# Processing Record great yarmouth of Set 607 | great yarmouth
# great yarmouth found. Record completed.
# Processing Record kulhudhuffushi of Set 607 | kulhudhuffushi
# kulhudhuffushi found. Record completed.
# Processing Record beihai of Set 607 | beihai
# beihai found. Record completed.
# Processing Record corn island of Set 607 | corn island
# corn island found. Record completed.
# Processing Record comodoro rivadavia of Set 607 | comodoro rivadavia
# comodoro rivadavia found. Record completed.
# Processing Record bengkulu of Set 607 | bengkulu
# bengkulu found. Record completed.
# Processing Record the valley of Set 607 | the valley
# the valley found. Record completed.
# Processing Record howard springs of Set 607 | howard springs
# howard springs found. Record completed.
# Processing Record victoria of Set 607 | victoria
# victoria found. Record completed.
# Processing Record lucatan of Set 607 | lucatan
# lucatan not found. Skipping...
# Processing Record longyearbyen of Set 607 | longyearbyen
# longyearbyen found. Record completed.
# Processing Record flinders of Set 607 | flinders
# flinders found. Record completed.
# Processing Record samusu of Set 607 | samusu
# samusu not found. Skipping...
# Processing Record port macquarie of Set 607 | port macquarie
# port macquarie found. Record completed.
# Processing Record rochegda of Set 607 | rochegda
# rochegda found. Record completed.
# Processing Record altay of Set 607 | altay
# altay found. Record completed.
# Processing Record gorontalo of Set 607 | gorontalo
# gorontalo found. Record completed.
# Processing Record kortkeros of Set 607 | kortkeros
# kortkeros found. Record completed.
# Processing Record saskylakh of Set 607 | saskylakh
# saskylakh found. Record completed.
# Processing Record vizinga of Set 607 | vizinga
# vizinga found. Record completed.
# Processing Record fare of Set 607 | fare
# fare found. Record completed.
# Processing Record zaraza of Set 607 | zaraza
# zaraza found. Record completed.
# Processing Record attawapiskat of Set 607 | attawapiskat
# attawapiskat not found. Skipping...
# Processing Record camacha of Set 607 | camacha
# camacha found. Record completed.
# Processing Record dawlatabad of Set 607 | dawlatabad
# dawlatabad found. Record completed.
# Processing Record svetlaya of Set 607 | svetlaya
# svetlaya found. Record completed.
# Processing Record ixtapa of Set 607 | ixtapa
# ixtapa found. Record completed.
# Processing Record ternovka of Set 607 | ternovka
# ternovka found. Record completed.
# Processing Record roma of Set 607 | roma
# roma found. Record completed.
# Processing Record gamboma of Set 607 | gamboma
# gamboma found. Record completed.
# Processing Record hami of Set 607 | hami
# hami found. Record completed.
# Processing Record ngunguru of Set 607 | ngunguru
# ngunguru found. Record completed.
# Processing Record guerrero negro of Set 607 | guerrero negro
# guerrero negro found. Record completed.
# Processing Record sao filipe of Set 607 | sao filipe
# sao filipe found. Record completed.
# Processing Record hovd of Set 607 | hovd
# hovd found. Record completed.
# Processing Record hobyo of Set 607 | hobyo
# hobyo found. Record completed.
# Processing Record sistranda of Set 607 | sistranda
# sistranda found. Record completed.
# Processing Record axim of Set 607 | axim
# axim found. Record completed.
# Processing Record qabis of Set 607 | qabis
# qabis not found. Skipping...
# Processing Record dwarka of Set 607 | dwarka
# dwarka found. Record completed.
# Processing Record tessalit of Set 607 | tessalit
# tessalit found. Record completed.
# Processing Record aklavik of Set 607 | aklavik
# aklavik found. Record completed.
# Processing Record kismayo of Set 607 | kismayo
# kismayo found. Record completed.
# Processing Record kavaratti of Set 607 | kavaratti
# kavaratti found. Record completed.
# Processing Record tamandare of Set 607 | tamandare
# tamandare found. Record completed.
# Processing Record faya of Set 607 | faya
# faya found. Record completed.
# Processing Record male of Set 607 | male
# male found. Record completed.
# Processing Record richards bay of Set 607 | richards bay
# richards bay found. Record completed.
# Processing Record balikpapan of Set 607 | balikpapan
# balikpapan found. Record completed.
# Processing Record rawson of Set 607 | rawson
# rawson found. Record completed.
# Processing Record aljezur of Set 607 | aljezur
# aljezur found. Record completed.
# Processing Record skagastrond of Set 607 | skagastrond
# skagastrond not found. Skipping...
# Processing Record barmer of Set 607 | barmer
# barmer found. Record completed.
# Processing Record platanos of Set 607 | platanos
# platanos found. Record completed.
# Processing Record jamiltepec of Set 607 | jamiltepec
# jamiltepec found. Record completed.
# Processing Record yabrud of Set 607 | yabrud
# yabrud found. Record completed.
# Processing Record amderma of Set 607 | amderma
# amderma not found. Skipping...
# Processing Record srednekolymsk of Set 607 | srednekolymsk
# srednekolymsk found. Record completed.
# Processing Record high level of Set 607 | high level
# high level found. Record completed.
# Processing Record chimbote of Set 607 | chimbote
# chimbote found. Record completed.
# Processing Record iwanai of Set 607 | iwanai
# iwanai found. Record completed.
# Processing Record sindand of Set 607 | sindand
# sindand not found. Skipping...
# Processing Record avenal of Set 607 | avenal
# avenal found. Record completed.
# Processing Record port lincoln of Set 607 | port lincoln
# port lincoln found. Record completed.
# Processing Record tefe of Set 607 | tefe
# tefe found. Record completed.
# Processing Record arlit of Set 607 | arlit
# arlit found. Record completed.
# Processing Record salinopolis of Set 607 | salinopolis
# salinopolis found. Record completed.
# Processing Record severo-kurilsk of Set 607 | severo-kurilsk
# severo-kurilsk found. Record completed.
# Processing Record san rafael del sur of Set 607 | san rafael del sur
# san rafael del sur found. Record completed.
# Processing Record kollam of Set 607 | kollam
# kollam found. Record completed.
# Processing Record hirara of Set 607 | hirara
# hirara found. Record completed.
# Processing Record zyryanka of Set 607 | zyryanka
# zyryanka found. Record completed.
# Processing Record el tigre of Set 607 | el tigre
# el tigre found. Record completed.
# Processing Record talnakh of Set 607 | talnakh
# talnakh found. Record completed.
# Processing Record hamilton of Set 607 | hamilton
# hamilton found. Record completed.
# Processing Record novikovo of Set 607 | novikovo
# novikovo found. Record completed.
# Processing Record adre of Set 607 | adre
# adre found. Record completed.
# Processing Record tazovskiy of Set 607 | tazovskiy
# tazovskiy found. Record completed.
# Processing Record sungai kolok of Set 607 | sungai kolok
# sungai kolok not found. Skipping...
# Processing Record taltal of Set 607 | taltal
# taltal found. Record completed.
# Processing Record saint-georges of Set 607 | saint-georges
# saint-georges found. Record completed.
# Processing Record badaojiang of Set 607 | badaojiang
# badaojiang not found. Skipping...
# Processing Record warri of Set 607 | warri
# warri found. Record completed.
# Processing Record quatre cocos of Set 607 | quatre cocos
# quatre cocos found. Record completed.
# Processing Record ngukurr of Set 607 | ngukurr
# ngukurr not found. Skipping...
# Processing Record clyde river of Set 607 | clyde river
# clyde river found. Record completed.
# Processing Record namibe of Set 607 | namibe
# namibe found. Record completed.
# Processing Record toyoshina of Set 607 | toyoshina
# toyoshina found. Record completed.
# Processing Record pulaski of Set 607 | pulaski
# pulaski found. Record completed.
# Processing Record ishigaki of Set 607 | ishigaki
# ishigaki found. Record completed.
# Processing Record rognan of Set 607 | rognan
# rognan found. Record completed.
# Processing Record mehamn of Set 607 | mehamn
# mehamn found. Record completed.
# Processing Record khalkhal of Set 607 | khalkhal
# khalkhal found. Record completed.
# Processing Record tucuman of Set 607 | tucuman
# tucuman found. Record completed.
# Processing Record cetraro of Set 607 | cetraro
# cetraro found. Record completed.
# Processing Record booue of Set 607 | booue
# booue found. Record completed.
# Processing Record marawi of Set 607 | marawi
# marawi found. Record completed.
# Processing Record kanigoro of Set 607 | kanigoro
# kanigoro found. Record completed.
# Processing Record north bend of Set 607 | north bend
# north bend found. Record completed.
# Processing Record fethiye of Set 607 | fethiye
# fethiye found. Record completed.
# Processing Record saint-pierre of Set 607 | saint-pierre
# saint-pierre found. Record completed.
# Processing Record giyani of Set 607 | giyani
# giyani found. Record completed.
# Processing Record beisfjord of Set 607 | beisfjord
# beisfjord found. Record completed.
# Processing Record port-cartier of Set 607 | port-cartier
# port-cartier found. Record completed.
# Processing Record martapura of Set 607 | martapura
# martapura found. Record completed.
# Processing Record bay roberts of Set 607 | bay roberts
# bay roberts found. Record completed.
# Processing Record vestmannaeyjar of Set 607 | vestmannaeyjar
# vestmannaeyjar found. Record completed.
# Processing Record kaseda of Set 607 | kaseda
# kaseda found. Record completed.
# Processing Record banda aceh of Set 607 | banda aceh
# banda aceh found. Record completed.
# Processing Record springfield of Set 607 | springfield
# springfield found. Record completed.
# Processing Record abiramam of Set 607 | abiramam
# abiramam found. Record completed.
# Processing Record saint-louis of Set 607 | saint-louis
# saint-louis found. Record completed.
# Processing Record moyo of Set 607 | moyo
# moyo found. Record completed.
# Processing Record tabuk of Set 607 | tabuk
# tabuk found. Record completed.
# Processing Record rudbar of Set 607 | rudbar
# rudbar found. Record completed.
# Processing Record carutapera of Set 607 | carutapera
# carutapera found. Record completed.
# Processing Record jurm of Set 607 | jurm
# jurm found. Record completed.
# Processing Record sharjah of Set 607 | sharjah
# sharjah found. Record completed.
# Processing Record cukai of Set 607 | cukai
# cukai found. Record completed.
# Processing Record port hedland of Set 607 | port hedland
# port hedland found. Record completed.
# Processing Record grindavik of Set 607 | grindavik
# grindavik found. Record completed.
# Processing Record takaka of Set 607 | takaka
# takaka found. Record completed.
# Processing Record aksarka of Set 607 | aksarka
# aksarka found. Record completed.
# Processing Record lancaster of Set 607 | lancaster
# lancaster found. Record completed.
# Processing Record plettenberg bay of Set 607 | plettenberg bay
# plettenberg bay found. Record completed.
# Processing Record imphal of Set 607 | imphal
# imphal found. Record completed.
# Processing Record french harbor of Set 607 | french harbor
# french harbor found. Record completed.
# Processing Record puntarenas of Set 607 | puntarenas
# puntarenas found. Record completed.
# Processing Record dukat of Set 607 | dukat
# dukat found. Record completed.
# Processing Record kieta of Set 607 | kieta
# kieta found. Record completed.
# Processing Record durban of Set 607 | durban
# durban found. Record completed.
# Processing Record beni of Set 607 | beni
# beni found. Record completed.
# Processing Record somogyvar of Set 607 | somogyvar
# somogyvar found. Record completed.
# Processing Record belyy yar of Set 607 | belyy yar
# belyy yar found. Record completed.
# Processing Record inuvik of Set 607 | inuvik
# inuvik found. Record completed.
# Processing Record isla mujeres of Set 607 | isla mujeres
# isla mujeres found. Record completed.
# Processing Record road town of Set 607 | road town
# road town found. Record completed.
# Processing Record makaha of Set 607 | makaha
# makaha found. Record completed.
# Processing Record berea of Set 607 | berea
# berea found. Record completed.
# Processing Record oistins of Set 607 | oistins
# oistins found. Record completed.
# Processing Record vao of Set 607 | vao
# vao found. Record completed.
# Processing Record jubayl of Set 607 | jubayl
# jubayl not found. Skipping...
# Processing Record beringovskiy of Set 607 | beringovskiy
# beringovskiy found. Record completed.
# Processing Record miraflores of Set 607 | miraflores
# miraflores found. Record completed.
# Processing Record gizo of Set 607 | gizo
# gizo found. Record completed.
# Processing Record tambacounda of Set 607 | tambacounda
# tambacounda found. Record completed.
# Processing Record grimstad of Set 607 | grimstad
# grimstad found. Record completed.
# Processing Record khonuu of Set 607 | khonuu
# khonuu not found. Skipping...
# Processing Record margate of Set 607 | margate
# margate found. Record completed.
# Processing Record milkovo of Set 607 | milkovo
# milkovo found. Record completed.
# Processing Record san carlos de bariloche of Set 607 | san carlos de bariloche
# san carlos de bariloche found. Record completed.
# Processing Record uspenka of Set 607 | uspenka
# uspenka found. Record completed.
# Processing Record cockburn town of Set 607 | cockburn town
# cockburn town found. Record completed.
# Processing Record tezu of Set 607 | tezu
# tezu found. Record completed.
# Processing Record narsaq of Set 607 | narsaq
# narsaq found. Record completed.
# Processing Record hokitika of Set 607 | hokitika
# hokitika found. Record completed.
# Processing Record nanakuli of Set 607 | nanakuli
# nanakuli found. Record completed.
# Processing Record winslow of Set 607 | winslow
# winslow found. Record completed.
# Processing Record itaituba of Set 607 | itaituba
# itaituba found. Record completed.
# Processing Record banmo of Set 607 | banmo
# banmo not found. Skipping...
# Processing Record zhuhai of Set 607 | zhuhai
# zhuhai found. Record completed.
# Processing Record togur of Set 607 | togur
# togur found. Record completed.
# Processing Record bien hoa of Set 607 | bien hoa
# bien hoa found. Record completed.
# Processing Record dharchula of Set 607 | dharchula
# dharchula found. Record completed.
# Processing Record aranos of Set 607 | aranos
# aranos found. Record completed.
# Processing Record umm lajj of Set 607 | umm lajj
# umm lajj found. Record completed.
# Processing Record prince albert of Set 607 | prince albert
# prince albert found. Record completed.
# Processing Record egvekinot of Set 607 | egvekinot
# egvekinot found. Record completed.
# Processing Record kloulklubed of Set 607 | kloulklubed
# kloulklubed found. Record completed.
# Processing Record maturin of Set 607 | maturin
# maturin found. Record completed.
# Processing Record capinzal of Set 607 | capinzal
# capinzal found. Record completed.
# Processing Record basco of Set 607 | basco
# basco found. Record completed.
# Processing Record komsomolskiy of Set 607 | komsomolskiy
# komsomolskiy found. Record completed.
# Processing Record damietta of Set 607 | damietta
# damietta found. Record completed.
# Processing Record airai of Set 607 | airai
# airai found. Record completed.
# Processing Record qinzhou of Set 607 | qinzhou
# qinzhou found. Record completed.
# Processing Record marovoay of Set 607 | marovoay
# marovoay found. Record completed.
# Processing Record joshimath of Set 607 | joshimath
# joshimath found. Record completed.
# Processing Record daxian of Set 607 | daxian
# daxian not found. Skipping...
# Processing Record maraa of Set 607 | maraa
# maraa found. Record completed.
# Processing Record jiamusi of Set 607 | jiamusi
# jiamusi found. Record completed.
# Processing Record cururupu of Set 607 | cururupu
# cururupu found. Record completed.
# Processing Record tchaourou of Set 607 | tchaourou
# tchaourou found. Record completed.
# Processing Record riyadh of Set 607 | riyadh
# riyadh found. Record completed.
# Processing Record kavieng of Set 607 | kavieng
# kavieng found. Record completed.
# Processing Record grand centre of Set 607 | grand centre
# grand centre not found. Skipping...
# Processing Record buenos aires of Set 607 | buenos aires
# buenos aires found. Record completed.
# Processing Record ankang of Set 607 | ankang
# ankang found. Record completed.
# Processing Record khani of Set 607 | khani
# khani found. Record completed.
# Processing Record dongzhen of Set 607 | dongzhen
# dongzhen found. Record completed.
# Processing Record petropavlovsk-kamchatskiy of Set 607 | petropavlovsk-kamchatskiy
# petropavlovsk-kamchatskiy found. Record completed.
# Processing Record lavrentiya of Set 607 | lavrentiya
# lavrentiya found. Record completed.
# Processing Record beterou of Set 607 | beterou
# beterou found. Record completed.
# Processing Record severomuysk of Set 607 | severomuysk
# severomuysk found. Record completed.
# Processing Record santa flavia of Set 607 | santa flavia
# santa flavia found. Record completed.
# Processing Record solnechnyy of Set 607 | solnechnyy
# solnechnyy found. Record completed.
# Processing Record iberia of Set 607 | iberia
# iberia found. Record completed.
# Processing Record bongandanga of Set 607 | bongandanga
# bongandanga found. Record completed.
# Processing Record lundamo of Set 607 | lundamo
# lundamo found. Record completed.
# Processing Record atlantic beach of Set 607 | atlantic beach
# atlantic beach found. Record completed.
# Processing Record bagotville of Set 607 | bagotville
# bagotville found. Record completed.
# Processing Record kamenka of Set 607 | kamenka
# kamenka found. Record completed.
# Processing Record marktredwitz of Set 607 | marktredwitz
# marktredwitz found. Record completed.
# Processing Record daru of Set 607 | daru
# daru found. Record completed.
# Processing Record sinnamary of Set 607 | sinnamary
# sinnamary found. Record completed.
# Processing Record fort nelson of Set 607 | fort nelson
# fort nelson found. Record completed.
# Processing Record mathathane of Set 607 | mathathane
# mathathane found. Record completed.
# Processing Record mirnyy of Set 607 | mirnyy
# mirnyy found. Record completed.
# Processing Record evensk of Set 607 | evensk
# evensk found. Record completed.
# Processing Record safaga of Set 607 | safaga
# safaga found. Record completed.
# Processing Record nizhnyaya tavda of Set 607 | nizhnyaya tavda
# nizhnyaya tavda found. Record completed.
# Processing Record barra of Set 607 | barra
# barra found. Record completed.
# Processing Record chapada dos guimaraes of Set 607 | chapada dos guimaraes
# chapada dos guimaraes found. Record completed.
# Processing Record kurtamysh of Set 607 | kurtamysh
# kurtamysh found. Record completed.
# Processing Record nikolayevsk-na-amure of Set 607 | nikolayevsk-na-amure
# nikolayevsk-na-amure found. Record completed.
# Processing Record luancheng of Set 607 | luancheng
# luancheng found. Record completed.
# Processing Record bol of Set 607 | bol
# bol found. Record completed.
# Processing Record cayenne of Set 607 | cayenne
# cayenne found. Record completed.
# Processing Record kahului of Set 607 | kahului
# kahului found. Record completed.
# Processing Record florence of Set 607 | florence
# florence found. Record completed.
# Processing Record todos santos of Set 607 | todos santos
# todos santos found. Record completed.
# Processing Record laguna of Set 607 | laguna
# laguna found. Record completed.
# Processing Record vila of Set 607 | vila
# vila found. Record completed.
# Processing Record celestun of Set 607 | celestun
# celestun found. Record completed.
# Processing Record butembo of Set 607 | butembo
# butembo found. Record completed.
# Processing Record balmazujvaros of Set 607 | balmazujvaros
# balmazujvaros found. Record completed.
# Processing Record darhan of Set 607 | darhan
# darhan found. Record completed.
# Processing Record loa janan of Set 607 | loa janan
# loa janan found. Record completed.
# Processing Record llangefni of Set 607 | llangefni
# llangefni found. Record completed.
# Processing Record liliani of Set 607 | liliani
# liliani found. Record completed.
# Processing Record telimele of Set 607 | telimele
# telimele found. Record completed.
# Processing Record kaeo of Set 607 | kaeo
# kaeo found. Record completed.
# Processing Record yialos of Set 607 | yialos
# yialos not found. Skipping...
# Processing Record victoria point of Set 607 | victoria point
# victoria point found. Record completed.
# Processing Record lake charles of Set 607 | lake charles
# lake charles found. Record completed.
# Processing Record staryy nadym of Set 607 | staryy nadym
# staryy nadym found. Record completed.
# Processing Record altamira of Set 607 | altamira
# altamira found. Record completed.
# Processing Record presidencia roque saenz pena of Set 607 | presidencia roque saenz pena
# presidencia roque saenz pena found. Record completed.
# Processing Record miri of Set 607 | miri
# miri found. Record completed.
# Processing Record ponta pora of Set 607 | ponta pora
# ponta pora found. Record completed.
# Processing Record trincomalee of Set 607 | trincomalee
# trincomalee found. Record completed.
# Processing Record tineo of Set 607 | tineo
# tineo found. Record completed.
# Processing Record kudahuvadhoo of Set 607 | kudahuvadhoo
# kudahuvadhoo found. Record completed.
# Processing Record kargasok of Set 607 | kargasok
# kargasok found. Record completed.
# Processing Record luhyny of Set 607 | luhyny
# luhyny found. Record completed.
# Processing Record husavik of Set 607 | husavik
# husavik found. Record completed.
# Processing Record xucheng of Set 607 | xucheng
# xucheng found. Record completed.
# Processing Record jining of Set 607 | jining
# jining found. Record completed.
# Processing Record temaraia of Set 607 | temaraia
# temaraia not found. Skipping...
# Processing Record broome of Set 607 | broome
# broome found. Record completed.
# Processing Record moiyabana of Set 607 | moiyabana
# moiyabana not found. Skipping...
# Processing Record paamiut of Set 607 | paamiut
# paamiut found. Record completed.
# Processing Record taoudenni of Set 607 | taoudenni
# taoudenni found. Record completed.
# Processing Record sain alto of Set 607 | sain alto
# sain alto found. Record completed.
# Processing Record progreso of Set 607 | progreso
# progreso found. Record completed.
# Processing Record manzil salim of Set 607 | manzil salim
# manzil salim found. Record completed.
# Processing Record burla of Set 607 | burla
# burla found. Record completed.
# Processing Record caravelas of Set 607 | caravelas
# caravelas found. Record completed.
# Processing Record santa marta of Set 607 | santa marta
# santa marta found. Record completed.
# Processing Record dhidhdhoo of Set 607 | dhidhdhoo
# dhidhdhoo found. Record completed.
# Processing Record tabiauea of Set 607 | tabiauea
# tabiauea not found. Skipping...
# Processing Record micheweni of Set 607 | micheweni
# micheweni found. Record completed.
# Processing Record kuche of Set 607 | kuche
# kuche not found. Skipping...
# Processing Record katobu of Set 607 | katobu
# katobu found. Record completed.
# Processing Record tilichiki of Set 607 | tilichiki
# tilichiki found. Record completed.
# Processing Record marakkanam of Set 607 | marakkanam
# marakkanam found. Record completed.
# Processing Record kasungu of Set 607 | kasungu
# kasungu found. Record completed.
# Processing Record mandera of Set 607 | mandera
# mandera found. Record completed.
# Processing Record rio gallegos of Set 607 | rio gallegos
# rio gallegos found. Record completed.
# Processing Record armacao de pera of Set 607 | armacao de pera
# armacao de pera found. Record completed.
# Processing Record sola of Set 607 | sola
# sola found. Record completed.
# Processing Record sandpoint of Set 607 | sandpoint
# sandpoint found. Record completed.
# Processing Record ukiah of Set 607 | ukiah
# ukiah found. Record completed.
# Processing Record pitanga of Set 607 | pitanga
# pitanga found. Record completed.
# Processing Record simao of Set 607 | simao
# simao found. Record completed.
# Processing Record raychikhinsk of Set 607 | raychikhinsk
# raychikhinsk found. Record completed.
# Processing Record mazamari of Set 607 | mazamari
# mazamari found. Record completed.
# Processing Record tarakan of Set 607 | tarakan
# tarakan found. Record completed.
# Processing Record chernyshevskiy of Set 607 | chernyshevskiy
# chernyshevskiy found. Record completed.
# Processing Record avanigadda of Set 607 | avanigadda
# avanigadda found. Record completed.
# Processing Record katsuura of Set 607 | katsuura
# katsuura found. Record completed.
# Processing Record ahuimanu of Set 607 | ahuimanu
# ahuimanu found. Record completed.
# ------------------------
# Data Retrieval Complete
# ------------------------

# %%
weather_summary = pd.DataFrame(
    {'City': city_list,
     'Lat': lat_list,
     'Lng': lon_list,
     'Max Temp' : max_temp_list,
     'Humidity': humidity_list,
     'Cloudiness' : cloudiness_list,
     'Wind Speed' : wind_list,
     'Country' : country_list,
     'Date' : date_list
    })

weather_summary.head()
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         rikitea -23.12 -134.97     74.21        80         100       20.98
# 1  saint-philippe -21.36   55.77     70.00        68          28        5.82
# 2  ribeira grande  38.52  -28.70     63.28        63          97       16.22
# 3      georgetown   5.41  100.34     77.00        94          40        5.82
# 4            chuy -33.70  -53.46     65.57        76          99       11.03
#
#   Country        Date
# 0      PF  1602972010
# 1      RE  1602971430
# 2      PT  1602971526
# 3      MY  1602971483
# 4      UY  1602971463

# %% [markdown]
# ## Convert Raw Data to DataFrame
# * Save as csv

# %%
weather_summary.to_csv("output_data/weather_summary.csv",
                  encoding="utf-8", index=False, header=True)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ### Latitude vs. Temperature Plot

# %%
## Convert to floats and store Poverty Rate and Bank Count as x and y values
x_values = weather_summary['Lat']
y_values = weather_summary['Max Temp']
date = weather_summary['Date'].mean()
date = datetime.utcfromtimestamp(date).strftime('%m-%d-%Y %H:%M:%S')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values, color="blue", edgecolors="black")

# Plot regression line
plt.plot(x_values,regress_values,"g-")
#plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.title(f'City Latitude vs Max Temerature ({date})')
plt.grid()


# Show plot
plt.savefig("output_data/City Latitude vs Max Temerature.png")
plt.show()

# %% [markdown]
# #### Observations:
#
# The data shows that today the temperatures have a correlation with latitude.  The closer to 0 (the equator) the hotter the temperature

# %% [markdown]
# ### Latitude vs. Humidity Plot

# %%
## Convert to floats and store Poverty Rate and Bank Count as x and y values
x_values = weather_summary['Lat']
y_values = weather_summary['Humidity']
date = weather_summary['Date'].mean()
date = datetime.utcfromtimestamp(date).strftime('%m-%d-%Y %H:%M:%S')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values, color="blue", edgecolors="black")

# Plot regression line
plt.plot(x_values,regress_values,"g-")
#plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f'City Latitude vs Humidity ({date})')
plt.grid()


# Show plot
plt.savefig("output_data/City Latitude vs Humidity.png")
plt.show()

# %% [markdown]
# #### Observations:
#
# The data shows that there is little to no correlation between humidity and latitude.
# However, higher humidities (80%) seem to be more common throughout all latitudes

# %% [markdown]
# ### Latitude vs. Cloudiness Plot

# %%
## Convert to floats and store Poverty Rate and Bank Count as x and y values
x_values = weather_summary['Lat']
y_values = weather_summary['Cloudiness']
date = weather_summary['Date'].mean()
date = datetime.utcfromtimestamp(date).strftime('%m-%d-%Y %H:%M:%S')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values, color="blue", edgecolors="black")

# Plot regression line
plt.plot(x_values,regress_values,"g-")
#plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f'City Latitude vs Cloudiness ({date})')
plt.grid()


# Show plot
plt.savefig("output_data/City Latitude vs Cloudiness.png")
plt.show()

# %% [markdown]
# #### Observations:
#
# The data shows that there is little to no correlation between cloudiness and latitude.

# %% [markdown]
# ### Latitude vs. Wind Speed Plot

# %%
## Convert to floats and store Poverty Rate and Bank Count as x and y values
x_values = weather_summary['Lat']
y_values = weather_summary['Wind Speed']
date = weather_summary['Date'].mean()
date = datetime.utcfromtimestamp(date).strftime('%m-%d-%Y %H:%M:%S')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values, color="blue", edgecolors="black")

# Plot regression line
plt.plot(x_values,regress_values,"g-")
#plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title(f'City Latitude vs Wind Speed ({date})')
plt.grid()


# Show plot
plt.savefig("output_data/City Latitude vs Wind Speed.png")
plt.show()

# %% [markdown]
# #### Observations:
#
# The data shows that there is little to no correlation between Wind Speed and latitude.
# The most common wind speeds tend to be slower within the 0-10 mph range.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ### Write linear regression plot function (optional)

# %%
# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %% [markdown]
# ###  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
## Convert to floats and store Poverty Rate and Bank Count as x and y values
north_hemi = weather_summary.loc[(
    weather_summary['Lat'] > 0)]

x_values = north_hemi['Lat']
y_values = north_hemi['Max Temp']
date = weather_summary['Date'].mean()
date = datetime.utcfromtimestamp(date).strftime('%m-%d-%Y %H:%M:%S')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values, color="blue", edgecolors="black")

# Plot regression line
plt.plot(x_values,regress_values,"g-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.title(f'North Hemisphere: City Latitude vs Max Temerature ({date})')
plt.grid()


# Show plot
plt.savefig("output_data/North Hemisphere: City Latitude vs Max Temerature.png")
plt.show()

print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.7466544802662429

# %% [markdown]
# #### Observations:
#
# The regression is modeling that there is a correlation.
# The Closer to 0 in latitude (the equator), the warmer the max temperature.

# %% [markdown]
# ###  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
## Convert to floats and store Poverty Rate and Bank Count as x and y values
south_hemi = weather_summary.loc[(
    weather_summary['Lat'] < 0)]

x_values = south_hemi['Lat']
y_values = south_hemi['Max Temp']
date = weather_summary['Date'].mean()
date = datetime.utcfromtimestamp(date).strftime('%m-%d-%Y %H:%M:%S')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"g-")
plt.annotate(line_eq,(-20,55),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.title(f'South Hemisphere: City Latitude vs Max Temerature ({date})')
plt.grid()


# Show plot
plt.savefig("output_data/South Hemisphere: City Latitude vs Max Temerature.png")
plt.show()

print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.4697237728024702

# %% [markdown]
# #### Observations:
#
# The regression is modeling that there is a correlation.
# The Closer to 0 in latitude (the equator), the warmer the max temperature.

# %% [markdown]
# ###  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
## Convert to floats and store Poverty Rate and Bank Count as x and y values
north_hemi = weather_summary.loc[(
    weather_summary['Lat'] > 0)]

x_values = north_hemi['Lat']
y_values = north_hemi['Humidity']
date = weather_summary['Date'].mean()
date = datetime.utcfromtimestamp(date).strftime('%m-%d-%Y %H:%M:%S')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"g-")
#plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f'North Hemisphere: City Latitude vs Humidity ({date})')
plt.grid()


# Show plot
plt.savefig("output_data/North Hemisphere: City Latitude vs Humidity.png")
plt.show()

print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.020827621417273758

# %% [markdown]
# #### Observations
#
# The regression is modeling that there is a slight to no correlation.
# The Closer to 0 in latitude (the equator), slightly lower the humidity.

# %% [markdown]
# ###  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
## Convert to floats and store Poverty Rate and Bank Count as x and y values
south_hemi = weather_summary.loc[(
    weather_summary['Lat'] < 0)]

x_values = south_hemi['Lat']
y_values = south_hemi['Humidity']
date = weather_summary['Date'].mean()
date = datetime.utcfromtimestamp(date).strftime('%m-%d-%Y %H:%M:%S')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"g-")
plt.annotate(line_eq,(-25,20),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f'South Hemisphere: City Latitude vs Humidity ({date})')
plt.grid()


# Show plot
plt.savefig("output_data/South Hemisphere: City Latitude vs Humidity.png")
plt.show()

print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.032093068116929524

# %% [markdown]
# #### Observations
#
# The regression is modeling that there is a slight to no correlation.
# The Closer to 0 in latitude (the equator), slightly higher the humidity.

# %% [markdown]
# ###  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
## Convert to floats and store Poverty Rate and Bank Count as x and y values
north_hemi = weather_summary.loc[(
    weather_summary['Lat'] > 0)]

x_values = north_hemi['Lat']
y_values = north_hemi['Cloudiness']
date = weather_summary['Date'].mean()
date = datetime.utcfromtimestamp(date).strftime('%m-%d-%Y %H:%M:%S')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"g-")
#plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f'North Hemisphere: City Latitude vs Cloudiness ({date})')
plt.grid()


# Show plot
plt.savefig("output_data/North Hemisphere: City Latitude vs Cloudiness.png")
plt.show()

print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.006825659368720453

# %% [markdown]
# #### Observations
#
# The regression is modeling that there is a slight to no correlation.
# The Closer to 0 in latitude (the equator), slightly lower the cloudiness.

# %% [markdown]
# ###  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
## Convert to floats and store Poverty Rate and Bank Count as x and y values
south_hemi = weather_summary.loc[(
    weather_summary['Lat'] < 0)]

x_values = south_hemi['Lat']
y_values = south_hemi['Cloudiness']
date = weather_summary['Date'].mean()
date = datetime.utcfromtimestamp(date).strftime('%m-%d-%Y %H:%M:%S')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"g-")
plt.annotate(line_eq,(-25,20),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f'Southern Hemisphere: City Latitude vs Cloudiness ({date})')
plt.grid()


# Show plot
plt.savefig("output_data/Southern Hemisphere: City Latitude vs Cloudiness.png")
plt.show()

print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.0032808885421671424

# %% [markdown]
# #### Observations
#
# The regression is modeling that there is a slight to no correlation.
# The Closer to 0 in latitude (the equator), slightly higher the cloudiness.

# %% [markdown]
# ###  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
## Convert to floats and store Poverty Rate and Bank Count as x and y values
north_hemi = weather_summary.loc[(
    weather_summary['Lat'] > 0)]

x_values = north_hemi['Lat']
y_values = north_hemi['Wind Speed']
date = weather_summary['Date'].mean()
date = datetime.utcfromtimestamp(date).strftime('%m-%d-%Y %H:%M:%S')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"g-")
#plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title(f'Northern Hemisphere: City Latitude vs Wind Speed ({date})')
plt.grid()


# Show plot
plt.savefig("output_data/Northern Hemisphere: City Latitude vs Wind Speed.png")
plt.show()

print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.0319302665142926

# %% [markdown]
# #### Observations
#
# The regression is modeling that there is a slight to no correlation.
# The Closer to 0 in latitude (the equator), slightly slower the Wind Speed.

# %% [markdown]
# ###  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
## Convert to floats and store Poverty Rate and Bank Count as x and y values
south_hemi = weather_summary.loc[(
    weather_summary['Lat'] < 0)]

x_values = south_hemi['Lat']
y_values = south_hemi['Wind Speed']
date = weather_summary['Date'].mean()
date = datetime.utcfromtimestamp(date).strftime('%m-%d-%Y %H:%M:%S')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"g-")
plt.annotate(line_eq,(-25,20),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title(f'Southern Hemisphere: City Latitude vs Wind Speed ({date})')
plt.grid()


# Show plot
plt.savefig("output_data/Southern Hemisphere: City Latitude vs Wind Speed.png")
plt.show()

print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.022141897717020898

# %% [markdown]
# #### Observations
#
# The regression is modeling that there is a slight to no correlation.
# The Closer to 0 in latitude (the equator), slightly slower the Wind Speed.
